# %%
import pandas as pd

# %%
df_1 = pd.read_csv("./dyn-LI-100-1/ExpressionData.csv",index_col=0)
df_2 = pd.read_csv("./dyn-LI-100-1/PseudoTime.csv",index_col=0)

df_1=df_1.T

result=pd.concat([df_2,df_1],axis=1)
result.sort_values('PseudoTime',inplace=True)

result
# Out:
#          PseudoTime        g1        g2        g3        g4        g5  \
# E98_3      0.000000  1.320946  0.305765  0.012767  0.012989  0.004983
# E10_3      0.000000  1.232829  0.309374  0.004167  0.040375  0.017173
# E11_8      0.010081  1.202342  0.803845  0.001676  0.014057  0.009532
# E99_21     0.036290  1.714308  1.263931  0.023217  0.007759  0.003190
# E17_24     0.042339  2.052661  1.167578  0.001447  0.028525  0.005132
# ...             ...       ...       ...       ...       ...       ...
# E43_476    0.953629  1.624194  1.278093  1.781741  2.331053  1.174517
# E70_481    0.963710  1.598076  2.034315  1.552367  2.031291  1.238823
# E56_489    0.979839  1.145267  1.453530  1.391505  1.858966  1.634341
# E78_498    0.997984  1.686711  1.659303  1.700112  1.857655  2.111207
# E95_499    1.000000  1.404810  1.408683  1.700424  1.285695  1.510907
#
#                g6        g7
# E98_3    0.035239  0.029232
# E10_3    0.003918  0.011440
# E11_8    0.043124  0.005194
# ...
